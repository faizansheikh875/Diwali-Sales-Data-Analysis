# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df  = pd.read_csv(r'C:\Users\faiza\Downloads\Python_Diwali_Sales_Analysis\Python_Diwali_Sales_Analysis\Diwali Sales Data.csv',encoding = 'unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %%
df.drop(['Status','unnamed1'], axis=1 ,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), str(8)
# memory usage: 1.1 MB

# %%
df['Amount'] = df['Amount'].astype(int)

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
df.rename(columns={'Zone':'ZONE'},inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'ZONE', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610858
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610858
# std       12.753866      1.114967   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
sns.countplot(x='Gender',data=df,hue='Gender')
plt.show()

# %%
df.groupby("Gender")["Amount"].sum()
# Out:
# Gender
# F    74335856.43
# M    31913276.00
# Name: Amount, dtype: float64

# %%
gender_amount = df.groupby("Gender")["Amount"].sum().reset_index().sort_values(by="Amount", ascending=False)

ax = sns.barplot(data=gender_amount, x='Gender', y='Amount')


for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', fontsize=10)

plt.title('Gender vs Total Amount')
plt.xlabel('Gender')
plt.ylabel('Total Amount')
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'ZONE', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
sns.countplot(data=df,x='Age Group',hue = 'Gender')
plt.show()

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'ZONE', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'AgeGroup'],
#       dtype='str')

# %%
state_orders = (
    df.groupby("State")["Orders"]
      .sum()
      .reset_index()
      .sort_values(by="Orders", ascending=False)
)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
ax = sns.barplot(x="State", y="Orders",hue = 'State', data=state_orders, palette="coolwarm",)

plt.xlabel("State")
plt.ylabel("Total Orders")
plt.title("State-wise Orders")

# Rotate x labels for readability
plt.xticks(rotation=45)

# Show values on bars
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2, height, 
            f'{int(height)}', ha='center', va='bottom')

plt.show()

# %%
ax = sns.countplot(data=df, x='Marital_Status')

plt.title('Marital Status vs Count')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'ZONE', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'AgeGroup'],
#       dtype='str')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.countplot(data=df, x='Marital_Status', hue='Gender')

# Add bar labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Marital Status vs Orders by Gender')
plt.xlabel('Marital Status')
plt.ylabel('Count of Orders')
plt.legend(title='Gender')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

occupation_counts = df['Occupation'].value_counts().nlargest(8).sort_values(ascending=True)

ax = occupation_counts.plot(kind='barh', figsize=(10, 6),)

# Add bar labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Top 8 Occupations by Count (Ascending Order)')
plt.xlabel('Count')
plt.ylabel('Occupation')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.countplot(data=df, x='Product_Category', order=df['Product_Category'].value_counts().index)

# Add bar labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Product Category Count')
plt.xlabel('Product Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
top5 = df.groupby('Product_Category')['Amount'].sum().sort_values(ascending=False).head(5)

ax = sns.barplot(x=top5.index, y=top5.values)

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', fontsize=10)

plt.title('Top 5 Product Category vs Total Amount')
plt.xlabel('Product Category')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# conclusion:
#
# Company should focus on married female customers aged 26–35 years in the states of Uttar Pradesh, Maharashtra, and Karnataka, as their order count is the highest.
#
# The top three occupations contributing to sales are Health, IT, and Aviation.
#
# The top three product categories generating maximum orders are Clothing, Food, and Electronics.
